# %% [markdown]
# # Python 101 - Variables and Data Types
#
# ### Python skills you’ll need to start using Python for data science
#
# Here's what you'll learn in this tutorial:
#
# - You'll also get an overview of Python syntax, variable assignment, and operators.
# - You'll learn about several basic numeric, string, and Boolean types that are built into Python.
# - Overview of Python's some built-in functions.
#
#
#
# Jupyter Notebooks are composed of blocks (called cells) of text and code.
#
# To get started, try running the code cell bellow (By presing the ► button, or clicking on the cell and pressing ctrl+enter on your keyboard).

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Now you know how to interact with the Python interpreter and execute Python code. It's time to dig into the Python language. First up is a discussion about variables and data types.
#
# Well Python has majorly two data type :
# - Immutable data type are the one that cannot be changed or modified and consist of numbers, strings, bools and tuples
# - Mutable data type are the one that can be changed, and consist of list, dictionaries and sets.
#
# # Data Types
# Now that you know how to interact with the Python interpreter and execute  Python code, it is time to dive into the basic data types in Python.
#
# As you can see, python has a number of built-in data types like Numbers, Strings, Lists, Dictionary, Tuples,  Sets.
#
# ![image.png](attachment:image.png)
#
# #### Variable assignment
# Here we create a variable called XXX and assign it the value of 0 using the
# operator =, which is called the assignment operator.
#
# Keep in mind you don't need to specify the data type when declaring a variable.
#
# Note that there are certain rules to follow and some words you can't use when naming a variable. For example print cannot be used because it already refers to the build-in print function.
#
#
# #### Function calls
#
# We call functions by putting parentheses after their name, and putting the inputs (or arguments) to the function in those parentheses.
#
# The function print() displays the value passed to it on the screen.

# %%
int_num = 2
float_num = 3.142
bool_num = True


text = "This is a text variable"

f_string = f"the number pi is equal to {float_num}"


print(float_num) # Calling the function print() and giving it the argument float num
print(bool_num)
print(f_string)
# Out:
# 3.142
# True
# the number pi is equal to 3.142

# %% [markdown]
# ## Numbers in Python
#
# Number data type store numeric values and can be integer, floating (real values) or complex. These values are defined as int, float and complex built-in class.
# Let's practice through some quick exemples :
#
# ####  Built-in functions for working with numbers : Arithmetic operations
#
#
#
# min and max return the minimum and maximum of their arguments, respectively...
#
# abs returns the absolute value of an argument:

# %% [markdown]
# ### Arithmetic operations

# %%
# Operator Name : Description
a = 3
b = 2.2

print(f"{a} plus {b} is equal to {a + b}") #Addition : Sum of a and b
print(f"{a} minus {b} is equal to {a - b}") #Subtraction : Difference of a and b
print(f"{a} times {b} is equal to {a * b}") #Multiplication : Product of a and b
print(f"{a} by {b} is equal to {a / b}") #True division : Quotient of a and b
print(f"{a} divided {b} is equal to {a // b}") #Floor division : Quotient of a and b, removing fractional parts
print(f"{a} modulus {b} is equal to {a % b}") #Modulus : Integer remainder after division of a by b
print(f"{a} Exponential {b} is equal to {a ** b}") #Exponentiation : a raised to the power of b
print(f"The negation of {a} is equal to {-a}") # Negation : The negative of a
# Out:
# 3 plus 2.2 is equal to 5.2
# 3 minus 2.2 is equal to 0.7999999999999998
# 3 times 2.2 is equal to 6.6000000000000005
# 3 by 2.2 is equal to 1.3636363636363635
# 3 divided 2.2 is equal to 1.0
# 3 modulus 2.2 is equal to 0.7999999999999998
# 3 Exponential 2.2 is equal to 11.211578456539659
# The negation of 3 is equal to -3

# %% [markdown]
# ### Comparison operators
#
# ### Membership operators
#
# ### Logical operators

# %% [markdown]
# ### Data conversion
#
# Appart from being numbers dada types, int and float can also be called as functions which convert their arguments to the corresponding type.

# %%
print(int(b))
print(float(a))
# Out:
# 2
# 3.0

# %% [markdown]
# ## Python Strings
# A string is a sequence of characters. Python does not have a char data type, unlike C++ or Java. We denote or declare the string values inside single quotes or double quotes.
#
# 'hello' is the same as "hello". Multi-line strings can be denoted using triple quotes.

# %%
a_simple_string = 'This is a string'
another_string = "This is another string"
multiline_string = """ This is a multiline string
====
.
"""



#print(multiline_string+a_simple_string)

# print(multiline_string*2)

# Print the first 20 characters
#print(multiline_string[0:20])

# Print the last 20 char
print(multiline_string[-15:])
# Out:
#  string
# ====
# .

# %% [markdown]
# F-strings provide a way to embed expressions inside string literals, using a minimal syntax. ... In Python source code, an f-string is a literal string, prefixed with 'f', which contains expressions inside braces. The expressions are replaced with their values.

# %%
# Let’s import all the necessary libraries.
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $
#   X \sim \mathcal{N}(\mu,\,\sigma^{2})\,.
# $

# %% [markdown]
# $
#     f(x) = \frac1{\sqrt{2\pi\sigma^2}}{exp}^\frac{x-\mu}{\sigma}
# $

# %%
fig, ax = plt.subplots()
x= np.arange(-4,4,0.001)
ax.set_title('N(0,$1^2$)')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.plot(x, norm.pdf(x))
ax.set_ylim(0,0.45)
plt.show()

# %%
print(len(x))
# Out:
# 1000

# %% [markdown]
# <code="language-python">
#     <span class='css-example'>This text has a nice colour</span></code="language-python">

# %%
fig, ax = plt.subplots()
x = np.linspace(-10,10,1000)
stdvs = [1.0, 2.0, 3.0, 4.0]
for s in stdvs:
    ax.plot(x, norm.pdf(x,scale=s), label='std=%.1f' % s)
    
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.set_title('Normal Distribution')
ax.legend(loc='best', frameon=True)
ax.set_ylim(0,0.45)
ax.grid(True)

# %%
fig, ax = plt.subplots()
x = np.linspace(-10,10,1000)
means = [-5.0,-2.0,0.0, 1.0, 2.0, 5.0]
for mean in means:
    ax.plot(x, norm.pdf(x,loc=mean), label='mean=%.1f' % mean)
    
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.set_title('Normal Distribution')
ax.legend(loc='best', frameon=True)
ax.set_ylim(0,0.45)
ax.grid(True)

# %% [markdown]
# norm.rvs generates random normal distribution numbers according to the scale which is the standard deviation, the loc which is the mean and the size. We create a histogram for the generated numbers and add the PDF.

# %%
fig, ax = plt.subplots()
# for distribution curve
x= np.arange(-4,4,0.001)
ax.plot(x, norm.pdf(x))
ax.set_title("Cumulative normal distribution")
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
# for fill_between
px=np.arange(-4,1,0.01)
ax.set_ylim(0,0.5)
ax.fill_between(px,norm.pdf(px),alpha=0.5, color='g')
# for text
ax.text(-1,0.1,"cdf(x)", fontsize=20)
plt.show()

# %% [markdown]
# #### Python Strings
# A string is a sequence of characters. Python does not have a char data type, unlike C++ or Java. We denote or declare the string values inside single quotes or double quotes.
#
# 'hello' is the same as "hello". Multi-line strings can be denoted using triple quotes.

# %%
# Out:
#  string
# ====
# .

# %% [markdown]
# ## Conclusion
# In this chapter, we provide a list of more array-related data structures or techniques you might want to know in the future. We will keep publishing more tutos and update the links in this article to help you conquer these topics one by one.
#
# We also provide some array/string related exercise for you.
# Try to solve these problems by yourself.

# %% [markdown]
# Calling functions and defining our own, and using Python's builtin documentation
#
# You've already seen and used functions such as print and abs, min, max... But Python has many more functions, and defining your own functions is a big part of python programming.
#
# In this lesson, you will learn more about using and defining functions.
# - Defining functions
# - Functions arguments
# - Functions Applied to Functions¶
#
#
#
#
#
#
# Booleans and Conditionals
# Using booleans for branching logic
#
# Lists
#
# Lists in Python represent ordered sequences of values. Here is an example of how to create them:
#
# We can put other types of things in lists:
# planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
#
# We can even make a list of lists: hands = [['J', 'Q', 'K'], ['2', '2', '2'], ['6', 'A', 'K']]
#
# Indexing¶
# Slicing
# Modifying lists
# Searching lists¶
#
#
# lists methods
#
# (list.append modifies a list by adding an item to the end)
# list.pop removes and returns the last element of a list:
#
#
# lists functions (len, sorted, sum, max..)
#
#
#
#
#
#
# Tuples are almost exactly the same as lists. They differ in just two ways.
#
# 1: The syntax for creating them uses parentheses instead of square brackets
# 2: They cannot be modified (they are immutable).
#
#
#
#
# Loops
# Loops are a way to repeatedly execute some code. Here's an example:
#
#
# The for loop specifies
#
# the variable name to use (in this case, planet)
# the set of values to loop over (in this case, planets)
# You use the word "in" to link them together.
#
# The object to the right of the "in" can be any object that supports iteration. Basically, if it can be thought of as a group of things, you can probably loop over it. In addition to lists, we can iterate over the elements of a tuple:
#
#
#
#
#
# while loops
# The other type of loop in Python is a while loop, which iterates until some condition is met:
#
#
# List comprehensions¶
# List comprehensions are one of Python's most beloved and unique features. The easiest way to understand them is probably to just look at a few examples:
#
# Working with External Libraries
#
#
# In this tutorial, you will learn about imports in Python, get some tips for working with unfamiliar libraries (and the objects they return), and dig into operator overloading.
#
# So far we've talked about types and functions which are built-in to the language.
#
# But one of the best things about Python (especially if you're a data scientist) is the vast number of high-quality custom libraries that have been written for it.
#
# Some of these libraries are in the "standard library", meaning you can find them anywhere you run Python. Other libraries can be easily added, even if they aren't always shipped with Python.
#
# Either way, we'll access this code with imports.
#
# We'll start our example by importing math from the standard library.
#
# import math
#
# print("It's math! It has type {}".format(type(math)))
#
# math is a module. A module is just a collection of variables (a namespace, if you like) defined by someone else. We can see all the names in math using the built-in function dir().
#
# print(dir(math))
#
# We can access these variables using dot syntax. Some of them refer to simple values, like math.pi:
#
# print("pi to 4 significant digits = {:.4}".format(math.pi))
#
# But most of what we'll find in the module are functions, like math.log:
#
# math.log(32, 2)
